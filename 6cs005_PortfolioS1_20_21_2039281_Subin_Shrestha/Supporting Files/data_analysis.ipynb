# %%
import matplotlib.pyplot as plt
from statistics import mean, stdev
import pylab

# %% [markdown]
# # Task2_A

# %%
original_time = [3.54136, 3.27827, 3.72438, 3.34107, 3.61651, 3.66029, 3.73083, 4.07393, 3.64318, 4.92446]
imrpoved_time = [2.63679, 2.31044, 2.36693, 2.67324, 2.51085, 2.50984, 2.66308, 2.69766, 2.71722, 2.54553]

# %%
t_in_sec = [i for i in range(10)]
plt.plot(t_in_sec, original_time,'-',color='g',  label = 'Original Function')
plt.plot(t_in_sec, imrpoved_time,'-', color='orange', label = 'Improved Function')
plt.xlabel('Number of Run')
plt.ylabel('Time in seconds')
plt.legend()
plt.show()

# %%
mean(original_time)
# Out:
# 3.753428

# %% [markdown]
# # Task2_B

# %%
#data  1600: average14.33190
data_avg = [14.82151,14.13092, 14.78231, 14.70618, 14.98662, 14.33190 ]
data_1500 = [14.69905, 14.74464, 16.05465, 13.68569, 13.49028, 13.51400, 16.39930, 16.23843, 13.92603, 15.46304]
data_1520 = [14.53455, 14.15232, 14.15746, 13.77699, 13.63474, 13.90268, 13.70724, 14.19219, 14.82493, 14.42607]
data_1540 = [14.43733, 14.16597, 14.98843, 15.69574, 14.59548, 14.22275, 14.59233, 14.27049, 16.48820, 14.36639]
data_1560 = [14.15399, 14.09451, 14.08974, 14.38786, 14.25786, 14.39615, 15.83907, 14.58477, 15.94543, 15.31238]
data_1580 = [15.04587, 14.56991, 14.60175, 14.80369, 15.29255, 14.81529, 15.29401, 15.08289, 15.35874, 15.00145]
data_1600 = [13.28931, 13.50725, 13.83275, 14.93189, 13.91260, 15.98777, 15.05064, 14.00499, 14.71634, 14.08542]

# %%
t_in_sec = [i for i in range(10)]
from matplotlib.pyplot import figure
figure(num=None, figsize=(15, 10), dpi=80, facecolor='w', edgecolor='k')
plt.plot(t_in_sec, data_1500,'-',  label = 'No. of Threads: 1500')
plt.plot(t_in_sec, data_1520,'-',  label = 'No. of Threads: 1520')
plt.plot(t_in_sec, data_1540,'-',  label = 'No. of Threads: 1540')
plt.plot(t_in_sec, data_1560,'-',  label = 'No. of Threads: 1560')
plt.plot(t_in_sec, data_1580,'-',  label = 'No. of Threads: 1580')
plt.plot(t_in_sec, data_1600,'-', label = 'No. of Threads: 1600')
plt.xlabel('Number of Run')
plt.ylabel('Time in seconds')
plt.legend()
plt.show()

# %%
thread_no = [1500, 1520, 1540,1560,1580,1600]
plt.scatter(thread_no, data_avg)
plt.xlabel('Number of Threads')
plt.ylabel('Time in seconds')
plt.show()

# %%
b = [136.59915,
136.51136,
136.50965,
136.56938,
136.48027,
136.45425,
136.47424,
136.46502,
136.46192,
136.46606]
mean(b)
# Out:
# 136.49913

# %%
a = [15.24570,
14.95672,
14.66667,
14.72703,
14.89622,
14.61538,
14.60511,
14.56440,
14.56669,
14.57694
]
mean(a)
# Out:
# 14.742086

# %%
c = [16.47418,
16.33655,
16.52581,
16.47705,
16.32894,
16.29129,
16.45596,
16.52852,
16.17783,
16.27570
]
mean(c)
# Out:
# 16.387183

# %% [markdown]
# # Task 3 A

# %%
#calculating mean
cuda = [0.21034, 0.15946, 0.16189, 0.15951, 0.16104, 0.16045, 0.16409, 0.15833, 0.15976, 0.16426 ]
original = [15.24570, 14.95672, 14.66667, 14.72703, 14.89622, 14.61538, 14.60511, 14.56440, 14.56669, 14.57694 ]
multithread = [16.47418, 16.33655, 16.52581, 16.47705, 16.32894, 16.29129, 16.45596, 16.52852, 16.17783, 16.27570 ]
print(mean(cuda), stdev(cuda))
print(mean(original), stdev(original))
print(mean(multithread), stdev(multithread))
# Out:
# 0.165913 0.015732450575517823
# 14.742086 0.2245470672858291
# 16.387183 0.12063580508198127

# %%
number_of_run = [i for i in range(10)]
from matplotlib.pyplot import figure
figure(num=None, figsize=(7, 5), dpi=80, facecolor='w', edgecolor='k')
plt.plot(number_of_run, cuda,'-',  label = 'Cuda')
plt.plot(number_of_run, original,'-',  label = 'Original')
plt.plot(number_of_run, multithread,'-', label = 'Multithread')
plt.xlabel('Number of Run')
plt.ylabel('Time in seconds')
plt.legend()
plt.show()

# %% [markdown]
# # Task 3 B

# %%
#calculating mean
blur_original = [0.07725, 0.05197,0.05206,0.04556,0.04706,0.04621,0.04707,0.04822,0.04695,0.04681]
blur_CUDA = [0.16803, 0.02686, 0.02661, 0.02651, 0.02642, 0.02692,0.02621, 0.02626, 0.02669, 0.02750]
print(mean(blur_original), stdev(blur_original))
print(mean(blur_CUDA), stdev(blur_CUDA))
# Out:
# 0.050916 0.00952336098467576
# 0.040801000000000004 0.0447052784479765
